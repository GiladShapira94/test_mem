# %%
import mlrun

# %%
project = mlrun.load_project('./')

# %%
# for one workflow run
project.run('main',watch=True)
# Out:
# <div>Pipeline running (id=8ee25944-42fa-432c-9870-ab598a9398c1), <a href="https://dashboard.default-tenant.app.cust-cs-il-3-5-2.iguazio-cd2.com/mlprojects/testing-0/jobs/monitor-workflows/workflow/8ee25944-42fa-432c-9870-ab598a9398c1" target="_blank"><b>click here</b></a> to view the details in MLRun UI</div>
# <h2>Run Results</h2><h3>[info] Workflow 8ee25944-42fa-432c-9870-ab598a9398c1 finished, state=Succeeded</h3><br>click the hyper links below to see detailed results<br><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>uid</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>parameters</th>
#       <th>results</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
# #for run and create 9 projects and workflows in parllel
# for i in range(0,10):
#     project = mlrun.load_project('./',name=f"testing-{i}")
#     project.run('main')
#     project.run('main',schedule='0 * * * *') #for create a schedulin workflow
